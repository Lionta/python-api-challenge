# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df['Max Temp'] = city_data_df['Max Temp']-273
city_data_df.head()
# Out:
#    City_ID       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       lebu -37.6167 -73.6500     10.23        62          98
# 1        1   tasiilaq  65.6145 -37.6368      1.24        90         100
# 2        2     dikson  73.5069  80.5464      1.55        76          42
# 3        3  hithadhoo  -0.6000  73.0833     28.45        71         100
# 4        4   takoradi   4.8845  -1.7554     27.01        83         100
#
#    Wind Speed Country        Date
# 0        1.77      CL  1685956034
# 1        0.74      GL  1685956035
# 2        3.02      RU  1685956035
# 3        1.50      MV  1685956035
# 4        2.70      GH  1685956035

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles = "OSM",
    size='Humidity'
)


# Display the map
# YOUR CODE HERE
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
city_data_df = city_data_df.query('(`Max Temp` > 20 and `Max Temp` < 28) and (`Wind Speed` < 5) and (Humidity < 70)')
# Drop any rows with null values
# YOUR CODE HERE
city_data_df = city_data_df.dropna()
# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 8          8   mozarlandia -14.7447  -50.5706     20.35        51           5
# 39        39       rikitea -23.1203 -134.9692     23.13        68           3
# 42        42        avarua -21.2078 -159.7750     22.73        64          91
# 45        45       tautira -17.7333 -149.1500     25.52        69          34
# 81        81          kars  40.6020   43.0950     22.40        37          40
# 99        99         rodez  44.5000    2.5833     22.32        64           0
# 127      127      taywarah  33.3500   64.4167     21.48        13           0
# 131      131  marsa matruh  31.3525   27.2453     24.70        48          34
# 158      158         mpigi   0.2250   32.3136     24.88        60          85
# 165      165         luena -11.7833   19.9167     26.44        24          87
# 168      168         elena  42.9333   25.8833     23.47        50          19
# 170      170        linkou  45.3000  130.2833     20.48        58          91
# 182      182         uetze  52.4651   10.2047     22.62        47           4
# 193      193         serov  59.6033   60.5787     21.00        24           0
# 200      200       bourges  47.2500    2.4167     22.17        60           1
# 239      239        namibe -15.1961   12.1522     23.98        49           0
# 256      256        shingu  33.7333  135.9833     23.28        69          98
# 259      259       colonia  50.9333    6.9500     22.96        49           0
# 270      270        hasaki  35.7333  140.8333     26.42        69         100
# 276      276  manzil salim  35.8567    8.4765     20.38        55         100
# 286      286          khor  47.8861  134.9464     20.13        65          17
# 294      294       banfora  10.6333   -4.7667     26.42        63         100
# 337      337  krasnoselkup  65.7000   82.4667     21.06        55          87
# 346      346     mount isa -20.7333  139.5000     23.02        49          40
# 358      358     kansanshi -12.0951   26.4273     25.48        32          19
# 372      372        gannan  47.9147  123.5031     24.33        27          99
# 374      374        ziarat  30.3823   67.7282     23.48        26           0
# 379      379        ripoll  42.2006    2.1903     22.15        65           5
# 385      385          hovd  48.0056   91.6419     24.40        21           5
# 396      396          teya  60.3778   92.6267     25.28        53          63
# 401      401   palafrugell  41.9174    3.1631     23.91        47          11
# 410      410     steinbach  50.1667    8.5667     24.81        37           0
# 416      416    dembi dolo   8.5333   34.8000     22.65        65          29
# 422      422      were ilu  10.6000   39.4333     20.25        44          59
# 423      423       rinteln  52.1860    9.0792     22.48        69           4
# 430      430       avallon  47.4833    3.9000     21.20        59           7
# 432      432         yumen  40.2833   97.2000     24.99        21          96
# 437      437          bako   5.7833   36.5667     25.94        52          70
# 442      442     faratsiho -19.4000   46.9500     20.15        42           0
# 460      460      carbonia  39.1672    8.5222     23.51        63           7
# 474      474       haapiti -17.5667 -149.8667     24.00        67          45
# 477      477          naze  28.3667  129.4833     22.54        68          98
# 489      489  saint george  37.1041 -113.5841     24.01        34           0
# 494      494        maghar  32.8898   35.4070     25.82        53           0
# 499      499     caravelas -17.7125  -39.2481     23.05        62         100
# 516      516   mujiayingzi  42.1167  118.7833     27.16        16          96
# 520      520         haifa  32.8156   34.9892     26.98        58          20
# 529      529         vaxjo  56.8777   14.8091     20.85        40           0
# 543      543        aktash  50.3000   87.7333     21.08        26          38
#
#      Wind Speed Country        Date
# 8          2.21      BR  1685956036
# 39         3.79      PF  1685956044
# 42         4.85      CK  1685956045
# 45         4.67      PF  1685956045
# 81         4.63      TR  1685956055
# 99         2.06      FR  1685956059
# 127        3.80      AF  1685956065
# 131        3.87      EG  1685956066
# 158        2.66      UG  1685956072
# 165        2.23      AO  1685956074
# 168        2.15      BG  1685956075
# 170        2.24      CN  1685956075
# 182        1.03      DE  1685956078
# 193        4.43      RU  1685956081
# 200        3.55      FR  1685956082
# 239        2.85      AO  1685956092
# 256        0.75      JP  1685956096
# 259        1.03      DE  1685956097
# 270        4.76      JP  1685956100
# 276        3.52      TN  1685956101
# 286        2.18      RU  1685956104
# 294        2.49      BF  1685956106
# 337        4.18      RU  1685956116
# 346        2.06      AU  1685956118
# 358        2.87      ZM  1685956121
# 372        3.35      CN  1685955926
# 374        3.46      PK  1685956124
# 379        1.34      ES  1685956125
# 385        4.83      MN  1685956126
# 396        4.44      RU  1685956129
# 401        1.34      ES  1685956130
# 410        4.12      DE  1685956132
# 416        1.20      ET  1685956133
# 422        3.66      ET  1685956134
# 423        1.54      DE  1685956135
# 430        3.97      FR  1685956136
# 432        4.39      CN  1685956137
# 437        1.09      ET  1685956138
# 442        1.71      MG  1685956140
# 460        2.13      IT  1685956145
# 474        4.11      PF  1685956149
# 477        4.01      JP  1685956149
# 489        4.63      US  1685956130
# 494        3.60      IL  1685956153
# 499        1.71      BR  1685956154
# 516        4.78      CN  1685956158
# 520        4.12      IL  1685956159
# 529        2.06      SE  1685956162
# 543        0.77      RU  1685956166

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name'] = ''
# Display sample data
# YOUR CODE HERE
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 8   mozarlandia      BR -14.7447  -50.5706        51
# 39      rikitea      PF -23.1203 -134.9692        68
# 42       avarua      CK -21.2078 -159.7750        64
# 45      tautira      PF -17.7333 -149.1500        69
# 81         kars      TR  40.6020   43.0950        37

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 # YOUR CODE HERE
params = {
    # YOUR CODE HERE
    "categories":"accommodation.hotel",
    "limit":20,
    "apiKey":geoapify_key  
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] =f"circle:{row['Lng']},{row['Lat']},{radius}" # YOUR CODE HERE
    params["bias"] = f"proximity:{row['Lng']},{row['Lat']}"# YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params) # YOUR CODE HERE
    
    # Convert the API response to JSON format
    name_address = name_address.json()# YOUR CODE HERE
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# mozarlandia - nearest hotel: No hotel found
# rikitea - nearest hotel: Chez Bianca & Benoit
# avarua - nearest hotel: Paradise Inn
# tautira - nearest hotel: No hotel found
# kars - nearest hotel: Grand Ani Hotel
# rodez - nearest hotel: Auberge du Château
# taywarah - nearest hotel: No hotel found
# marsa matruh - nearest hotel: صقور
# mpigi - nearest hotel: No hotel found
# luena - nearest hotel: No hotel found
# elena - nearest hotel: Хотел "Тара"
# linkou - nearest hotel: No hotel found
# uetze - nearest hotel: Gasthaus Wilhelmshöhe
# serov - nearest hotel: отель Надеждинский
# bourges - nearest hotel: No hotel found
# namibe - nearest hotel: Hotel Chik Chik Namibe
# shingu - nearest hotel: ホテルニューパレス
# colonia - nearest hotel: Wasserturm Hotel Cologne
# hasaki - nearest hotel: 大新旅館
# manzil salim - nearest hotel: No hotel found
# khor - nearest hotel: No hotel found
# banfora - nearest hotel: Hotel-Calypso
# krasnoselkup - nearest hotel: No hotel found
# mount isa - nearest hotel: Ibis Styles
# kansanshi - nearest hotel: Paka Lodge
# gannan - nearest hotel: No hotel found
# ziarat - nearest hotel: No hotel found
# ripoll - nearest hotel: Hotel La Trobada
# hovd - nearest hotel: Khovd hotel
# teya - nearest hotel: No hotel found
# palafrugell - nearest hotel: Hostal Plaja
# steinbach - nearest hotel: Alt Steinbach
# dembi dolo - nearest hotel: No hotel found
# were ilu - nearest hotel: No hotel found
# rinteln - nearest hotel: Hotel Stadt Kassel
# avallon - nearest hotel: Le Pub Vauban
# yumen - nearest hotel: No hotel found
# bako - nearest hotel: Goh Hotel
# faratsiho - nearest hotel: No hotel found
# carbonia - nearest hotel: Lu' Hotel
# haapiti - nearest hotel: Pension Kahekaro
# naze - nearest hotel: ビジネス旅館畠山
# saint george - nearest hotel: The Advenire, an Autograph Collection Hotel
# maghar - nearest hotel: Mantur by Selina
# caravelas - nearest hotel: Pousada dos Navegantes
# mujiayingzi - nearest hotel: No hotel found
# haifa - nearest hotel: The Colony Hotel Haifa
# vaxjo - nearest hotel: Elite Stadshotellet
# aktash - nearest hotel: Акташ (Стонт)
#              City Country      Lat       Lng  Humidity  \
# 8     mozarlandia      BR -14.7447  -50.5706        51
# 39        rikitea      PF -23.1203 -134.9692        68
# 42         avarua      CK -21.2078 -159.7750        64
# 45        tautira      PF -17.7333 -149.1500        69
# 81           kars      TR  40.6020   43.0950        37
# 99          rodez      FR  44.5000    2.5833        64
# 127      taywarah      AF  33.3500   64.4167        13
# 131  marsa matruh      EG  31.3525   27.2453        48
# 158         mpigi      UG   0.2250   32.3136        60
# 165         luena      AO -11.7833   19.9167        24
# 168         elena      BG  42.9333   25.8833        50
# 170        linkou      CN  45.3000  130.2833        58
# 182         uetze      DE  52.4651   10.2047        47
# 193         serov      RU  59.6033   60.5787        24
# 200       bourges      FR  47.2500    2.4167        60
# 239        namibe      AO -15.1961   12.1522        49
# 256        shingu      JP  33.7333  135.9833        69
# 259       colonia      DE  50.9333    6.9500        49
# 270        hasaki      JP  35.7333  140.8333        69
# 276  manzil salim      TN  35.8567    8.4765        55
# 286          khor      RU  47.8861  134.9464        65
# 294       banfora      BF  10.6333   -4.7667        63
# 337  krasnoselkup      RU  65.7000   82.4667        55
# 346     mount isa      AU -20.7333  139.5000        49
# 358     kansanshi      ZM -12.0951   26.4273        32
# 372        gannan      CN  47.9147  123.5031        27
# 374        ziarat      PK  30.3823   67.7282        26
# 379        ripoll      ES  42.2006    2.1903        65
# 385          hovd      MN  48.0056   91.6419        21
# 396          teya      RU  60.3778   92.6267        53
# 401   palafrugell      ES  41.9174    3.1631        47
# 410     steinbach      DE  50.1667    8.5667        37
# 416    dembi dolo      ET   8.5333   34.8000        65
# 422      were ilu      ET  10.6000   39.4333        44
# 423       rinteln      DE  52.1860    9.0792        69
# 430       avallon      FR  47.4833    3.9000        59
# 432         yumen      CN  40.2833   97.2000        21
# 437          bako      ET   5.7833   36.5667        52
# 442     faratsiho      MG -19.4000   46.9500        42
# 460      carbonia      IT  39.1672    8.5222        63
# 474       haapiti      PF -17.5667 -149.8667        67
# 477          naze      JP  28.3667  129.4833        68
# 489  saint george      US  37.1041 -113.5841        34
# 494        maghar      IL  32.8898   35.4070        53
# 499     caravelas      BR -17.7125  -39.2481        62
# 516   mujiayingzi      CN  42.1167  118.7833        16
# 520         haifa      IL  32.8156   34.9892        58
# 529         vaxjo      SE  56.8777   14.8091        40
# 543        aktash      RU  50.3000   87.7333        26
#
#                                       Hotel Name
# 8                                 No hotel found
# 39                          Chez Bianca & Benoit
# 42                                  Paradise Inn
# 45                                No hotel found
# 81                               Grand Ani Hotel
# 99                            Auberge du Château
# 127                               No hotel found
# 131                                         صقور
# 158                               No hotel found
# 165                               No hotel found
# 168                                 Хотел "Тара"
# 170                               No hotel found
# 182                        Gasthaus Wilhelmshöhe
# 193                           отель Надеждинский
# 200                               No hotel found
# 239                       Hotel Chik Chik Namibe
# 256                                    ホテルニューパレス
# 259                     Wasserturm Hotel Cologne
# 270                                         大新旅館
# 276                               No hotel found
# 286                               No hotel found
# 294                                Hotel-Calypso
# 337                               No hotel found
# 346                                  Ibis Styles
# 358                                   Paka Lodge
# 372                               No hotel found
# 374                               No hotel found
# 379                             Hotel La Trobada
# 385                                  Khovd hotel
# 396                               No hotel found
# 401                                 Hostal Plaja
# 410                                Alt Steinbach
# 416                               No hotel found
# 422                               No hotel found
# 423                           Hotel Stadt Kassel
# 430                                Le Pub Vauban
# 432                               No hotel found
# 437                                    Goh Hotel
# 442                               No hotel found
# 460                                    Lu' Hotel
# 474                             Pension Kahekaro
# 477                                     ビジネス旅館畠山
# 489  The Advenire, an Autograph Collection Hotel
# 494                             Mantur by Selina
# 499                       Pousada dos Navegantes
# 516                               No hotel found
# 520                       The Colony Hotel Haifa
# 529                          Elite Stadshotellet
# 543                                Акташ (Стонт)

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles = "OSM",
    hover_cols=['Hotel Name', 'Country'],
    size="Humidity"
)
# Display the map
# YOUR CODE HERE
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,Hotel Name,Country)
